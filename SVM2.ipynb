# %%
import numpy as np
from sklearn import datasets
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %%
dt=pd.read_csv("/Users/AntoineTamagno/Documents/iris.txt",index_col=None,delimiter=",")
dt.columns=['SL','SW','PL','PW','Type of flower']
dt.head()
# Out:
#     SL   SW   PL   PW Type of flower
# 0  4.9  3.0  1.4  0.2    Iris-setosa
# 1  4.7  3.2  1.3  0.2    Iris-setosa
# 2  4.6  3.1  1.5  0.2    Iris-setosa
# 3  5.0  3.6  1.4  0.2    Iris-setosa
# 4  5.4  3.9  1.7  0.4    Iris-setosa

# %%
sns.countplot(x='Type of flower', data=dt, palette='hls')

# %%
sns.pairplot(dt, hue='Type of flower')

# %%
sns.heatmap(dt.corr())

# %%
X=dt[['SL','SW','PL','PW']].values
y=dt['Type of flower'].values
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=.3, random_state=25)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='poly',degree=8)
classifier.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=8, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test, y_pred))  
print(classification_report(y_test, y_pred))
# Out:
# [[17  0  0]
#  [ 0 11  2]
#  [ 0  1 14]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.92      0.85      0.88        13
#  Iris-virginica       0.88      0.93      0.90        15
#
#     avg / total       0.93      0.93      0.93        45

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
dtc.score(X_test, y_test)
# Out:
# 0.9555555555555556

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix
# Out:
# array([[17,  0,  0],
#        [ 0, 11,  2],
#        [ 0,  1, 14]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.92      0.85      0.88        13
#  Iris-virginica       0.88      0.93      0.90        15
#
#     avg / total       0.93      0.93      0.93        45

# %%
LogReg = LogisticRegression()
LogReg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_perd=LogReg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_perd)
confusion_matrix
# Out:
# array([[17,  0,  0],
#        [ 0, 10,  3],
#        [ 0,  0, 15]])

# %%
print(classification_report(y_test, y_perd))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       1.00      0.77      0.87        13
#  Iris-virginica       0.83      1.00      0.91        15
#
#     avg / total       0.94      0.93      0.93        45
